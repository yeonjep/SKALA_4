# %% [markdown]
# ### 전처리 조별

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from itertools import combinations

# 노트북 안에서 그래프가 셀 바로 아래에 바로 뜨도록 설정
# %matplotlib inline

# 자주 쓸 상수
TARGET = "Machine failure"
NUMERIC_VARS = [
    "Air temperature [K]",
    "Process temperature [K]",
    "Rotational speed [rpm]",
    "Torque [Nm]",
    "Tool wear [min]",
]
OUT_DIR = "outputs"
os.makedirs(OUT_DIR, exist_ok=True)

pd.set_option("display.max_columns", None)  # 열 잘리지 않고 다 보이게
